# %% [markdown]
# ## This script calculates auPR, auROC and F1 scores for test portion of the Topic CREs, the non-augmented version

# %%
import os
import sys
import random
import numpy as np
import pandas as pd
import crested
import pickle

# %%
dataDir='/home/p541i/MBsnANA/HBana/ISM/Outs/'
out_Dir='/home/p541i/MBsnANA/HBana/ISM/Outs/'
os.chdir(out_Dir)

# %%
bed_files=dataDir+'TopicMP_CREs'
chromsizes=dataDir+'extrafiles/chromSizes_canchrom.genome'
adata = crested.import_beds(
    beds_folder=bed_files, chromsizes_file=chromsizes
)  # the regions file is optional for import_beds
#adata

# %%
##Load the test split
with open('OutfrmGPU/deephb_testsplit_lstmv2_57MP_040525.pkl', 'rb') as f:
    test_part=pickle.load( f)

# %%
df=adata.var

# %%
arr1 = test_part.index.astype(str).to_list()
arr2 = df.index.astype(str).to_list()

# %%
common = set(arr1) & set(arr2)
print(len(arr1))
print(len(arr2))
print(len(common))

# %%
# common is test part of adata, it is 10%
adata_subset = adata[:, list(common)]
adata_subset

# %% [markdown]
# #### Now loading the models and running prediction to obtain metric values

# %%
import keras
genome_fasta=dataDir+'extrafiles/gencdH38p13r37.fa'

# %%
##load model
#model_path = dataDir+"extrafiles/deephb_lstmv3_57MP_53.keras"
#model_path = dataDir+"extrafiles/deephb_lstmv2_57MP_73.keras"
model_path = dataDir+"extrafiles/deephb_cnn_57MP_99.keras"

# %%
model = keras.models.load_model(
    model_path, compile=False
)  #

# %%
prediction = crested.tl.predict(adata_subset, model,genome=genome_fasta)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752424378.179599 2587225 service.cc:152] XLA service 0x55ac00af1e70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752424378.179635 2587225 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-07-13 18:32:58.707912: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#   51/8941 ━━━━━━━━━━━━━━━━━━━━ 27s 3ms/step
# I0000 00:00:1752424382.777691 2587225 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 8941/8941 ━━━━━━━━━━━━━━━━━━━━ 29s 3ms/step

# %%
#with open(os.path.join('OutfrmGPU/HBCRE_test/predHBCRE_test_deephb_lstmv2_57MP_73.pkl'), 'wb') as f:
#      pickle.dump(prediction, f)

# %%
#with open(os.path.join('OutfrmGPU/HBCRE_test/predHBCRE_test_deephb_lstmv3_57MP_53.pkl'), 'wb') as f:
#     pickle.dump(prediction, f)

# %%
with open(os.path.join('OutfrmGPU/HBCRE_test/predHBCRE_test_deephb_cnn_57MP_99.pkl'), 'wb') as f:
      pickle.dump(prediction, f)

# %% [markdown]
# #### Obtianing metric values

# %%
with open(os.path.join('TopicMPs.txt'), "r") as file:
    labels = file.read().splitlines()
print(labels)
# Out:
# ['MP10', 'MP11', 'MP12', 'MP13', 'MP14', 'MP15', 'MP16', 'MP17', 'MP18', 'MP19', 'MP1', 'MP20', 'MP21', 'MP22', 'MP23', 'MP24', 'MP25', 'MP26', 'MP27', 'MP28', 'MP29', 'MP2', 'MP30', 'MP31', 'MP32', 'MP33', 'MP34', 'MP35', 'MP36', 'MP37', 'MP38', 'MP39', 'MP3', 'MP40', 'MP41', 'MP42', 'MP43', 'MP44', 'MP45', 'MP46', 'MP47', 'MP48', 'MP49', 'MP4', 'MP50', 'MP51', 'MP52', 'MP53', 'MP54', 'MP55', 'MP56', 'MP57', 'MP5', 'MP6', 'MP7', 'MP8', 'MP9']

# %%
gt=adata_subset.X.T #ground turth
print(gt.shape)
gt_rs=gt.sum(axis=1)
# Out:
# (8941, 57)

# %% [markdown]
# ## F1 scores

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

# %%
# Actual binary labels and predicted scores
# gt: ground truth, shape (n_CREs, 57)
# prediction: obtained score, shape (n_CREs, 57)

best_thresholds = []
best_f1s = []
all_metrics = []

thresholds = np.arange(0.00, 1.01, 0.01)

for i in range(57):  # For each Topic MP 
    y_t = gt[:, i]
    y_s = prediction[:, i]

    best_f1 = 0
    best_thresh = 0
    metrics_for_factor = []

    for thresh in thresholds:
        y_pred = (y_s >= thresh).astype(int)
        precision = precision_score(y_t, y_pred, zero_division=0)
        recall = recall_score(y_t, y_pred, zero_division=0)
        f1 = f1_score(y_t, y_pred, zero_division=0)

        metrics_for_factor.append((thresh, precision, recall, f1))

        if f1 > best_f1:
            best_f1 = f1
            best_thresh = thresh

    best_thresholds.append(best_thresh)
    best_f1s.append(best_f1)
    all_metrics.append(metrics_for_factor)

# %%
### Save best thresholdsimport pandas as pd

summary_data = []
## 67 classes
for idx in range(57):
    # Extract metrics at the best threshold
    best_thresh = best_thresholds[idx]
    metrics = next((m for m in all_metrics[idx] if m[0] == best_thresh), None)

    summary_data.append({
        "MP": labels[idx],
        "Best Threshold": best_thresh,
        "Precision": metrics[1],
        "Recall": metrics[2],
        "F1 Score": metrics[3]
    })

#print(summary_df)

# %%
summary_df = pd.DataFrame(summary_data)
#summary_df.to_csv("OutfrmGPU/HBCRE_test/MP_threshold_summary_deephb_lstmv2_57MP_73.txt", sep='\t')
#summary_df.to_csv("OutfrmGPU/HBCRE_test/MP_threshold_summary_deephb_lstmv3_57MP_53.txt", sep='\t')
summary_df.to_csv("OutfrmGPU/HBCRE_test/MP_threshold_summary_deephb_cnn_57MP_99.txt", sep='\t')

# %% [markdown]
# ## auPR and auROC values

# %%
adata_subset.layers["predict"] = prediction.T  # adata expects (C, N) instead of (N, C)

# %%
import tensorflow as tf

# %%
auPR_values = []
auROC_values = []


for i in range(gt.shape[1]):
    roc = tf.keras.metrics.AUC(curve='ROC')
    roc.update_state(gt[:, i], prediction[:, i])
    auROC = roc.result().numpy()
    auROC_values.append(auROC)
    
    pr = tf.keras.metrics.AUC(curve='PR')
    pr.update_state(gt[:, i], prediction[:, i])
    auPR = pr.result().numpy()
    auPR_values.append(auPR)
    

    #print(f"Class {labels[i]}: auROC={auROC:.4f}, auPR={auPR:.4f}")

macro_auPR = np.mean(auPR_values)
macro_auROC = np.mean(auROC_values)

print(f"Macro-Average auPR: {macro_auPR}")
print(f"Macro-Average auROC: {macro_auROC}")
# Out:
# Macro-Average auPR: 0.5047042965888977
# Macro-Average auROC: 0.9359556436538696

# %%
#obtain values for box plot
data = {'ROC': auROC_values, 'PR': auPR_values}
df = pd.DataFrame(data)

# Print the DataFrame (optional)
#print(df)

# Save the DataFrame to a CSV file
#df.to_csv('OutfrmGPU/HBCRE_test/ROC_PR_deephb_lstmv2_73.txt', index=False,sep='\t')
#df.to_csv('OutfrmGPU/HBCRE_test/ROC_PR_deephb_lstmv3_53.txt', index=False,sep='\t')
df.to_csv('OutfrmGPU/HBCRE_test/ROC_PR_deephb_cnn_99.txt', index=False,sep='\t')

# %%
##read the picle file
with open('OutfrmGPU/met_deephb_lstmv3_57MP_050525.pkl', 'rb') as f:
    met_test_lstm=pickle.load( f)

met_test_lstm
# Out:
# {'auPR': 0.49749428033828735,
#  'auROC': 0.9184029698371887,
#  'categorical_accuracy': 0.38874492049217224,
#  'loss': 0.07600507140159607}

# %%
##read the picle file
with open('OutfrmGPU/met_deephb_lstmv2_57MP_090525.pkl', 'rb') as f:
    met_test_lstm=pickle.load( f)

met_test_lstm
# Out:
# {'auPR': 0.5260633826255798,
#  'auROC': 0.9223165512084961,
#  'categorical_accuracy': 0.4036236107349396,
#  'loss': 0.07331190258264542}

# %%
##read the picle file
with open('OutfrmGPU/met_deephb_lstmv2_57MP_090525.pkl', 'rb') as f:
    met_test_lstm=pickle.load( f)

met_test_lstm
# Out:
# {'auPR': 0.5260633826255798,
#  'auROC': 0.9223165512084961,
#  'categorical_accuracy': 0.4036236107349396,
#  'loss': 0.07331190258264542}
